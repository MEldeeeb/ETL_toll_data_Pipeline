# %% [markdown]
# Starting Zookepeer

# %% [markdown]
# ![Start_zookeper.jpg](attachment:Start_zookeper.jpg)

# %% [markdown]
# Starting Kafka server

# %% [markdown]
# ![Start_kafka_server-2.jpg](attachment:Start_kafka_server-2.jpg)
